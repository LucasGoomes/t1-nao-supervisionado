# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import cluster
from collections import Counter
import numpy as np

# %% [markdown]
# ### Original data

# %%
df_cb_original = pd.read_csv('data/cleaned_data/CB_original.csv')

df_cm_original = pd.read_csv('data/cleaned_data/CM_original.csv')

df_lb_original = pd.read_csv('data/cleaned_data/LB_original.csv')

# %% [markdown]
# ### Prepared training data

# %%
df_cb = pd.read_csv('data/prepared_data_2/by_position/kmeans/CB.csv')
df_cb_players = pd.read_csv('data/prepared_data_2/by_position/kmeans/CB_names.csv')

df_cm = pd.read_csv('data/prepared_data_2/by_position/kmeans/CM.csv')
df_cm_players = pd.read_csv('data/prepared_data_2/by_position/kmeans/CM_names.csv')

df_lb = pd.read_csv('data/prepared_data_2/by_position/kmeans/LB.csv')
df_lb_players = pd.read_csv('data/prepared_data/by_position/kmeans/LB_names.csv')

# %% [markdown]
# ## CB Position

# %%
k_means_cb = cluster.KMeans(n_clusters=2, max_iter=50, init='random',n_init=25, random_state=123)
k_means_cb.fit(df_cb)
# Out:
# KMeans(init='random', max_iter=50, n_clusters=2, n_init=25, random_state=123)

# %%
labels = k_means_cb.labels_
df_cb_original['cluster'] = labels
df_cb_original['Player Name'] = df_cb_players

# %%
df_cb_original.head(2)
df_cb_original.to_csv(f'data/final_data/DB_final.csv', index=False)

# %%
df_cb_original_numeric = df_cb_original.drop('Player Name', axis=1) 

cluster_means = df_cb_original_numeric.groupby('cluster').mean()  
cluster_means.head()
# Out:
#                Age    Overall  Potential       Value       Wage  \
# cluster
# 0        26.387626  67.082071  71.204545  221.208081  88.787879
# 1        28.513841  73.235294  75.230104   97.911419  56.435986
#
#          International Reputation  Weak Foot  Skill Moves      Height  \
# cluster
# 0                        1.063131   2.719697     2.005051  187.671717
# 1                        1.406574   2.965398     2.140138  185.544983
#
#             Weight  ...    Marking  StandingTackle  SlidingTackle   GKDiving  \
# cluster             ...
# 0        80.804293  ...  73.664373       68.253788      65.789600  10.606061
# 1        79.782007  ...  73.831050       73.951557      71.889428  10.486159
#
#          GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause  \
# cluster
# 0         10.436869  10.506313      10.441919   10.436869      151.614402
# 1         10.622837  10.849481      10.762976   10.562284       83.527830
#
#          DefensiveAwareness
# cluster
# ...

# %%
cluster_medians = df_cb_original_numeric.groupby('cluster').median()  
cluster_medians.head()
# Out:
#           Age  Overall  Potential  Value  Wage  International Reputation  \
# cluster
# 0        26.0     67.0       71.0   3.10   5.0                       1.0
# 1        29.0     73.0       75.0   5.25  14.0                       1.0
#
#          Weak Foot  Skill Moves  Height  Weight  ...    Marking  \
# cluster                                          ...
# 0              3.0          2.0   188.0    80.0  ...  73.734694
# 1              3.0          2.0   186.0    80.0  ...  73.734694
#
#          StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# cluster
# 0                  68.0           65.0      11.0        10.0       11.0
# 1                  74.0           72.0      10.0        10.0       10.0
#
#          GKPositioning  GKReflexes  Release Clause  DefensiveAwareness
# cluster
# 0                 10.0        10.0            4.10                66.0
# 1                 11.0        10.0            9.35                72.0
#
# [2 rows x 46 columns]

# %% [markdown]
# ## CM Position

# %%
k_means_cm = cluster.KMeans(n_clusters=2, max_iter=50, init='random',n_init=25, random_state=123)
k_means_cm.fit(df_cm)
# Out:
# KMeans(init='random', max_iter=50, n_clusters=2, n_init=25, random_state=123)

# %%
labels = k_means_cm.labels_
df_cm_original['cluster'] = labels
df_cm_original['Player Name'] = df_cm_players

# %%
df_cm_original.head(2)
df_cm_original.to_csv(f'data/final_data/CM_final.csv', index=False)

# %%
df_cm_original_numeric = df_cm_original.drop('Player Name', axis=1) 

cluster_means = df_cm_original_numeric.groupby('cluster').mean()  
cluster_means.head()
# Out:
#                Age    Overall  Potential       Value       Wage  \
# cluster
# 0        25.246347  66.584551  71.300626  236.013779  82.624217
# 1        28.231362  74.113111  76.107969   66.583805  42.742931
#
#          International Reputation  Weak Foot  Skill Moves      Height  \
# cluster
# 0                        1.020877   3.060543     2.546973  178.924843
# 1                        1.413882   3.303342     3.061697  179.174807
#
#             Weight  ...    Marking  StandingTackle  SlidingTackle   GKDiving  \
# cluster             ...
# 0        72.762004  ...  58.764818       61.302714      57.914405  10.718163
# 1        73.665810  ...  58.707500       66.596401      61.923221  10.457584
#
#          GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause  \
# cluster
# 0         10.655532  10.496868      10.536534   10.496868      125.849370
# 1         10.655527  11.128535      10.455013   10.493573       48.438721
#
#          DefensiveAwareness
# cluster
# ...

# %%
cluster_medians = df_cm_original_numeric.groupby('cluster').median()  
cluster_medians.head()
# Out:
#           Age  Overall  Potential  Value  Wage  International Reputation  \
# cluster
# 0        25.0     67.0       71.0    2.9   4.0                       1.0
# 1        28.0     73.0       76.0    4.7  15.0                       1.0
#
#          Weak Foot  Skill Moves  Height  Weight  ...   Marking  \
# cluster                                          ...
# 0              3.0          3.0   179.0    72.0  ...  58.73913
# 1              3.0          3.0   179.0    74.0  ...  58.73913
#
#          StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# cluster
# 0                  63.0           60.0      11.0        11.0       10.0
# 1                  68.0           64.0      11.0        11.0       11.0
#
#          GKPositioning  GKReflexes  Release Clause  DefensiveAwareness
# cluster
# 0                 10.0        11.0             3.4                61.0
# 1                 10.0        10.0             9.5                66.0
#
# [2 rows x 46 columns]

# %% [markdown]
# ## LB Position

# %%
k_means_lb = cluster.KMeans(n_clusters=2, max_iter=50, init='random',n_init=25, random_state=123)
k_means_lb.fit(df_lb)
# Out:
# KMeans(init='random', max_iter=50, n_clusters=2, n_init=25, random_state=123)

# %%
labels = k_means_lb.labels_
df_lb_original['cluster'] = labels
df_lb_original['Player Name'] = df_lb_players

# %%
df_lb_original.head(2)
df_lb_original.to_csv(f'data/final_data/LB_final.csv', index=False)

# %%
df_lb_original_numeric = df_lb_original.drop('Player Name', axis=1) 

cluster_means = df_lb_original_numeric.groupby('cluster').mean()  
cluster_means.head()
# Out:
#                Age    Overall  Potential       Value        Wage  \
# cluster
# 0        28.100402  73.297189  75.088353   96.117269   45.911647
# 1        24.815789  65.650376  70.511278  276.616165  101.462406
#
#          International Reputation  Weak Foot  Skill Moves      Height  \
# cluster
# 0                        1.297189   2.883534     2.951807  177.598394
# 1                        1.000000   2.781955     2.304511  179.071429
#
#             Weight  ...    Marking  StandingTackle  SlidingTackle   GKDiving  \
# cluster             ...
# 0        72.385542  ...  70.594378       70.827309      69.632288  10.706827
# 1        72.327068  ...  70.411654       62.827068      61.515038  10.372180
#
#          GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause  \
# cluster
# 0         10.526104  10.955823      10.538153   10.538153       51.863677
# 1         10.462406  10.172932      10.406015   10.428571      159.122328
#
#          DefensiveAwareness
# cluster
# ...

# %%
cluster_medians = df_lb_original_numeric.groupby('cluster').median()  
cluster_medians.head()
# Out:
#           Age  Overall  Potential  Value  Wage  International Reputation  \
# cluster
# 0        28.0     73.0       75.0   4.90  13.0                       1.0
# 1        24.0     66.0       70.0   4.25   3.0                       1.0
#
#          Weak Foot  Skill Moves  Height  Weight  ...  Marking  StandingTackle  \
# cluster                                          ...
# 0              3.0          3.0   178.0    72.0  ...     70.5            71.0
# 1              3.0          2.0   180.0    72.0  ...     70.5            63.0
#
#          SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  \
# cluster
# 0                 69.0      11.0        11.0       11.0           10.0
# 1                 62.0      10.0        10.0       10.0           11.0
#
#          GKReflexes  Release Clause  DefensiveAwareness
# cluster
# 0              11.0             8.2                68.0
# 1              10.0             3.8                61.0
#
# [2 rows x 46 columns]
